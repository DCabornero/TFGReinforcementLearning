# %%
from Bandit import randomBandit,epsilonGreedy

bandit = randomBandit('ratings.csv')
bandit.run_epoch(epochs=5000)
# Out:
# [2.61983776 0.         0.        ]

# %%
from Bandit import epsilonGreedy

bandit = epsilonGreedy('ratings.csv',epsilon=0.1,alpha=0.1,initial=0.5)
bandit.run_epoch(epochs=100000)

# %%
from Bandit import thompsonSampling

bandit = thompsonSampling('ratings.csv')
bandit.run_epoch(epochs=50000)
# Out:
# [142.94059825   0.           0.        ]
